# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-и-подготовка-данных-к-анализу" data-toc-modified-id="Загрузка-и-подготовка-данных-к-анализу-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка и подготовка данных к анализу</a></span></li><li><span><a href="#Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии" data-toc-modified-id="Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Функции для расчета и анализа LTV, ROI, удержания и конверсии</a></span><ul class="toc-item"><li><span><a href="#Функция-для-создания-пользовательских-профилей" data-toc-modified-id="Функция-для-создания-пользовательских-профилей-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Функция для создания пользовательских профилей</a></span></li><li><span><a href="#Функция-для-расчёта-LTV-и-ROI" data-toc-modified-id="Функция-для-расчёта-LTV-и-ROI-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Функция для расчёта LTV и ROI</a></span></li><li><span><a href="#Функция-для-визуализации-LTV-и-ROI" data-toc-modified-id="Функция-для-визуализации-LTV-и-ROI-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Функция для визуализации LTV и ROI</a></span></li><li><span><a href="#Функция-для-сглаживания-датафрейма" data-toc-modified-id="Функция-для-сглаживания-датафрейма-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Функция для сглаживания датафрейма</a></span></li><li><span><a href="#Функция-для-расчёта-удержания" data-toc-modified-id="Функция-для-расчёта-удержания-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Функция для расчёта удержания</a></span></li><li><span><a href="#Функция-для-расчёта-конверсии" data-toc-modified-id="Функция-для-расчёта-конверсии-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Функция для расчёта конверсии</a></span></li><li><span><a href="#Функция-для-визуализации-удержания" data-toc-modified-id="Функция-для-визуализации-удержания-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Функция для визуализации удержания</a></span></li><li><span><a href="#Функция-для-визуализации-конверсии" data-toc-modified-id="Функция-для-визуализации-конверсии-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Функция для визуализации конверсии</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-пользовательских-профилей" data-toc-modified-id="Исследовательский-анализ-пользовательских-профилей-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ пользовательских профилей</a></span></li><li><span><a href="#Исследование-затрат-на-маркетинг" data-toc-modified-id="Исследование-затрат-на-маркетинг-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследование затрат на маркетинг</a></span></li><li><span><a href="#Оценка-окупаемости-рекламы-для-привлечения-пользователей" data-toc-modified-id="Оценка-окупаемости-рекламы-для-привлечения-пользователей-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Оценка окупаемости рекламы для привлечения пользователей</a></span><ul class="toc-item"><li><span><a href="#Анализ-общей-окупаемости-рекламы" data-toc-modified-id="Анализ-общей-окупаемости-рекламы-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Анализ общей окупаемости рекламы</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-устройствам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-устройствам-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по устройствам</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-странам-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по странам</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-рекламным-каналам-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по рекламным каналам</a></span></li><li><span><a href="#Анализ-конверсии-и-удержания" data-toc-modified-id="Анализ-конверсии-и-удержания-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Анализ конверсии и удержания</a></span></li></ul></li><li><span><a href="#Общие-выводы" data-toc-modified-id="Общие-выводы-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общие выводы</a></span></li></ul></div>

# %% [markdown]
# # Исследование окупаемости приложения

# %% [markdown]
# Вы — маркетинговый аналитик развлекательного приложения Procrastinate Pro+. Несмотря на огромные вложения в рекламу, последние несколько месяцев компания терпит убытки. Цель исследования — разобраться в причинах убытков и помочь компании выйти в плюс.
#
# Имеются данные о пользователях, привлечённых с 1 мая по 27 октября 2019 года:
# - лог сервера с данными об их посещениях,
# - выгрузка их покупок за этот период,
# - рекламные расходы.
#
# Изучим следующие вопросы:
# - откуда приходят пользователи и какими устройствами они пользуются,
# - сколько стоит привлечение пользователей из различных рекламных каналов,
# - сколько денег приносит каждый клиент,
# - когда расходы на привлечение клиента окупаются,
# - какие факторы мешают привлечению клиентов.

# %% [markdown]
# <div style="border:solid black 1px; padding: 20px">
#
# **Описание данных**
#
# Файл `visits_info_short.csv` хранит лог сервера с информацией о посещениях сайта, `orders_info_short.csv` — информацию о покупках, а `costs_info_short.csv` — информацию о расходах на рекламу.
#
# Структура `visits_info_short.csv`:
# - `User Id` — уникальный идентификатор пользователя,
# - `Region` — страна пользователя,
# - `Device` — тип устройства пользователя,
# - `Channel` — идентификатор источника перехода,
# - `Session Start` — дата и время начала сессии,
# - `Session End` — дата и время окончания сессии.
#
# Структура `orders_info_short.csv`:
# - `User Id` — уникальный идентификатор пользователя,
# - `Event Dt` — дата и время покупки,
# - `Revenue` — сумма заказа.
#
# Структура `costs_info_short.csv`:
# - `Channel` — идентификатор рекламного источника,
# - `Dt` — дата проведения рекламной кампании,
# - `Costs` — расходы на эту кампанию.
#
# </div>

# %% [markdown]
# **Импорт библиотек**

# %%
# импортируем необходимые библиотеки

import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt          
import seaborn as sns    
from datetime import datetime, timedelta

# %% [markdown]
# ## Загрузка и подготовка данных к анализу

# %%
# чтение данных из файла и их сохранение в переменные
visits = pd.read_csv('/datasets/visits_info_short.csv')
orders = pd.read_csv('/datasets/orders_info_short.csv')
costs = pd.read_csv('/datasets/costs_info_short.csv')

# выводим первые 10 строк
display(visits.head(10))
display(orders.head(10))
display(costs.head(10))
# Out:
#         User Id         Region   Device         Channel        Session Start  \
# 0  981449118918  United States   iPhone         organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone         organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac         organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android          TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac         organic  2019-05-01 03:33:35
# 5   90242400005  United States   iPhone  RocketSuperAds  2019-05-01 07:14:52
# 6   43958116050  United States  Android         organic  2019-05-01 09:03:21
# 7  185365244969  United States   iPhone         organic  2019-05-01 09:37:03
# 8  446013509831  United States   iPhone  RocketSuperAds  2019-05-01 10:26:00
# 9  100970711362  United States      Mac          TipTop  2019-05-01 04:39:53
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# ...

# %%
# получим общую информацию о данных
visits.info()
print()
orders.info()
print()
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# ...

# %%
# приведем наименования столбцов к нижнему и змеиному регистру
visits.columns = (visits.columns
                 .str.lower()
                 .str.replace(' ', '_'))
orders.columns = (orders.columns
                 .str.lower()
                 .str.replace(' ', '_'))
costs.columns = (costs.columns
                 .str.lower()
                 .str.replace(' ', '_'))

visits.columns, orders.columns, costs.columns
# Out:
# (Index(['user_id', 'region', 'device', 'channel', 'session_start',
#         'session_end'],
#        dtype='object'),
#  Index(['user_id', 'event_dt', 'revenue'], dtype='object'),
#  Index(['dt', 'channel', 'costs'], dtype='object'))

# %%
# проверим наличие неявных дубликатов и получим уникальные значения в столбцах 'region', 'device' в датафрейме visits
visits['region'].unique(), visits['device'].unique()
# Out:
# (array(['United States', 'UK', 'France', 'Germany'], dtype=object),
#  array(['iPhone', 'Mac', 'Android', 'PC'], dtype=object))

# %%
# проверим наличие неявных дубликатов и получим уникальные значения в столбцах 'channel' в датафреймах visits и costs
visits['channel'].sort_values().unique(), costs['channel'].sort_values().unique()
# Out:
# (array(['AdNonSense', 'FaceBoom', 'LeapBob', 'MediaTornado',
#         'OppleCreativeMedia', 'RocketSuperAds', 'TipTop', 'WahooNetBanner',
#         'YRabbit', 'lambdaMediaAds', 'organic'], dtype=object),
#  array(['AdNonSense', 'FaceBoom', 'LeapBob', 'MediaTornado',
#         'OppleCreativeMedia', 'RocketSuperAds', 'TipTop', 'WahooNetBanner',
#         'YRabbit', 'lambdaMediaAds'], dtype=object))

# %%
# преобразуем столбцы, содержащие дату и время, к специальному типу для хранения даты и времени
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# получим общую информацию о данных
visits.info()
print()
orders.info()
print()
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  datetime64[ns]
#  5   session_end    309901 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 14.2+ MB
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  datetime64[ns]
#  2   revenue   40212 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 942.6 KB
#
# ...

# %%
# отобразим минимальные и максимальные даты
print('visits session_start',visits['session_start'].min(), visits['session_start'].max())
print('visits session_end  ',visits['session_end'].min(), visits['session_end'].max())
print('orders event_dt     ',orders['event_dt'].min(), orders['event_dt'].max())
print('costs dt            ',costs['dt'].min(), costs['dt'].max())
# Out:
# visits session_start 2019-05-01 00:00:41 2019-10-31 23:59:23
# visits session_end   2019-05-01 00:07:06 2019-11-01 01:38:46
# orders event_dt      2019-05-01 00:28:11 2019-10-31 23:56:56
# costs dt             2019-05-01 2019-10-27

# %%
# проверка на наличие дубликатов
visits.duplicated().sum(), orders.duplicated().sum(), costs.duplicated().sum()
# Out:
# (0, 0, 0)

# %% [markdown]
# <div style="border:solid green 3px; padding: 20px">
#
# **Промежуточный вывод**
#
# Датафрейм `visits` содержит 309 901 строк и 6 столбцов.
#
# Датафрейм `orders` содержит 40 212 строк и 3 столбца.
#
# Датафрейм `costs` содержит 1 800 строк и 3 столбца.
#
# Наименования столбцов отражают суть, содержащихся в них данных. Названия столбцов привели к нижнему и змеиному регистру. Данные в столбцах, содержащих дату и время, привели к тпиу данных для хранения даты и времени. Встречающиеся типы данных - целые и вещественные числа, строковые значения и тип даты и времени.
#
# Пропущенные значения и дубликаты во всех датафреймах отсутствуют.
#
# </div>

# %% [markdown]
# ## Функции для расчета и анализа LTV, ROI, удержания и конверсии

# %% [markdown]
# ### Функция для создания пользовательских профилей

# %%
def get_profiles(sessions, orders, ad_costs):
    
    """функция для создания пользовательских профилей"""  

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# ### Функция для расчёта LTV и ROI

# %%
def get_ltv(profiles, purchases, observation_date, horizon_days, dimensions=[], ignore_horizon=False):
    
    """функция для расчёта LTV и ROI"""
    
    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(days=horizon_days - 1)
        
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']


    def group_by_dimensions(df, dims, horizon_days):
        """функция группировки по желаемым признакам"""
        
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time  # таблица динамики ROI
    )

# %% [markdown]
# ### Функция для визуализации LTV и ROI

# %%
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):
    
    """функция для визуализации LTV и ROI"""

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 30))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(3, 2, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(3, 2, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(3, 2, 3)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(3, 2, 4, sharey=ax3)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(3, 2, 5)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для сглаживания датафрейма

# %%
def filter_data(df, window):
    
    """функция для сглаживания фрейма"""
    
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# ### Функция для расчёта удержания

# %%
def get_retention(profiles, sessions, observation_date, horizon_days, dimensions=[], ignore_horizon=False):
    
    """функция для расчёта удержания"""
    
    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(days=horizon_days - 1)
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(result_raw, dimensions + ['dt'], horizon_days)

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для расчёта конверсии

# %%
def get_conversion(profiles, purchases, observation_date, horizon_days, dimensions=[], ignore_horizon=False):
    
    """функция для расчёта конверсии"""

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(days=horizon_days - 1)
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (result_raw['event_dt'] - result_raw['first_ts']).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(result_raw, dimensions + ['dt'], horizon_days)

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для визуализации удержания

# %%
def plot_retention(retention, retention_history, horizon, window=7):
    
    """функция для визуализации удержания"""

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика удержания платящих пользователей на {}-й день'.format(horizon))

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика удержания неплатящих пользователей на {}-й день'.format(horizon))
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для визуализации конверсии

# %%
def plot_conversion(conversion, conversion_history, horizon, window=7):
    
    """функция для визуализации конверсии"""

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Исследовательский анализ пользовательских профилей

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color='Black'>
# Построим профили пользователей. Определим минимальную и максимальную дату привлечения пользователей.
#
# Проанализируем:
# - Из каких стран приходят посетители? Какие страны дают больше всего платящих пользователей?
# - Какими устройствами они пользуются? С каких устройств чаще всего заходят платящие пользователи?
# - По каким рекламным каналам шло привлечение пользователей? Какие каналы приносят больше всего платящих пользователей?
#
# </font>
# </div>

# %%
# воспользуемся функцией для создания пользовательских профилей
user_profiles = get_profiles(visits, orders, costs)
user_profiles.head(10)
# Out:
#     user_id            first_ts       channel   device         region  \
# 0    599326 2019-05-07 20:58:57      FaceBoom      Mac  United States
# 1   4919697 2019-07-09 12:46:07      FaceBoom   iPhone  United States
# 2   6085896 2019-10-01 09:58:33       organic   iPhone         France
# 3  22593348 2019-08-22 21:35:48    AdNonSense       PC        Germany
# 4  31989216 2019-10-02 00:07:44       YRabbit   iPhone  United States
# 5  34186288 2019-05-09 17:29:23       organic  Android  United States
# 6  38448301 2019-08-16 11:56:00       organic  Android  United States
# 7  46006712 2019-06-30 03:46:29    AdNonSense  Android         France
# 8  58263264 2019-05-11 19:18:43      FaceBoom   iPhone  United States
# 9  59835779 2019-05-11 21:13:47  MediaTornado   iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# ...

# %%
# определим минимальную и максимальную даты привлечения пользователей
print('Минимальная дата привлечения пользователей ', user_profiles['first_ts'].min().date())
print('Максимальная дата привлечения пользователей ', user_profiles['first_ts'].max().date())
# Out:
# Минимальная дата привлечения пользователей  2019-05-01
# Максимальная дата привлечения пользователей  2019-10-27

# %%
def plot_user_distribution(profiles, column):
    
    """функция, строящая графики распределения всех пользователей 
    и платящих пользователей по заданному признаку column"""
    
    # группируем пользователей по признаку column отдельно по всем пользователям
    # и отдельно по платящим пользователям
    profiles_group = profiles.groupby(column).agg({'user_id':'count'})
    profiles_group_payer = profiles.query('payer == True').groupby(column).agg({'user_id':'count'})

    # построим графики пользователей распределений
    fig, axes = plt.subplots(1, 2)
    
    column_dict = {'region':'странам',
                   'device':'устройствам',
                   'channel':'каналам привлечения'}

    # заголовок области Figure
    fig.suptitle(f'Распределение пользователей по {column_dict[column]}', y = 1, fontsize = 16)

    axes[0].pie(profiles_group['user_id'], 
            labels=profiles_group.index, 
            labeldistance=1.1, 
            wedgeprops = {'linewidth' : 3, 'edgecolor' : 'white'}, 
            autopct='%.1f', 
            radius = 1.1)
    axes[0].set_title('Все пользователи')


    axes[1].pie(profiles_group_payer['user_id'], 
            labels=profiles_group_payer.index, 
            labeldistance=1.1, 
            wedgeprops = {'linewidth' : 3, 'edgecolor' : 'white'}, 
            autopct='%.1f', 
            radius = 1.1)
    axes[1].set_title('Платящие пользователи')

    fig.set_figheight(8)
    fig.set_figwidth(24)
    plt.show()

# %%
def user_distribution(profiles, column):
    
    """функция, строящая таблицу с количеством пользователей и долей платящих пользователей 
    в разрезе признака column"""
    
    profiles_group = (profiles
                     .groupby(column)
                     .agg({'user_id':'count','payer':'mean'})
                     .rename(columns={'user_id': 'user_count','payer':'%_payer'}))
    profiles_group['%_payer'] = round(profiles_group['%_payer'] * 100, 2)
    profiles_group = profiles_group.sort_values('user_count', ascending=False)
    
    return profiles_group

# %%
# воспользуемся функцией, строящей графики распределения всех пользователей 
# и платящих пользователей по заданному признаку
plot_user_distribution(user_profiles, 'region')

# %%
# воспользуемся функцией, строящей таблицу с количеством пользователей и долей платящих пользователей 
# в разрезе заданного признака 
profiles_group = user_distribution(user_profiles, 'region')
profiles_group
# Out:
#                user_count  %_payer
# region
# United States      100002     6.90
# UK                  17575     3.98
# France              17450     3.80
# Germany             14981     4.11

# %%
# воспользуемся функцией, строящей графики распределения всех пользователей 
# и платящих пользователей по заданному признаку
plot_user_distribution(user_profiles, 'device')

# %%
# воспользуемся функцией, строящей таблицу с количеством пользователей и долей платящих пользователей 
# в разрезе заданного признака 
profiles_group = user_distribution(user_profiles, 'device')
profiles_group
# Out:
#          user_count  %_payer
# device
# iPhone        54479     6.21
# Android       35032     5.85
# PC            30455     5.05
# Mac           30042     6.36

# %%
# воспользуемся функцией, строящей графики распределения всех пользователей 
# и платящих пользователей по заданному признаку
plot_user_distribution(user_profiles, 'channel')

# %%
# воспользуемся функцией, строящей таблицу с количеством пользователей и долей платящих пользователей 
# в разрезе заданного признака 
profiles_group = user_distribution(user_profiles, 'channel')
profiles_group
# Out:
#                     user_count  %_payer
# channel
# organic                  56439     2.06
# FaceBoom                 29144    12.20
# TipTop                   19561     9.60
# OppleCreativeMedia        8605     2.71
# LeapBob                   8553     3.06
# WahooNetBanner            8553     5.30
# RocketSuperAds            4448     7.91
# MediaTornado              4364     3.57
# YRabbit                   4312     3.83
# AdNonSense                3880    11.34
# lambdaMediaAds            2149    10.47

# %% [markdown]
# <div style="border:solid green 3px; padding: 20px">
#
# **Промежуточный вывод**
#
# Пользователи приходят из четырех стран United States, UK, France, Germany. Наибольшая доля платящих пользователей приходит из United States - 77,7% платящих пользователей. Доля других стран существенно ниже: UK - 7,9%, France - 7,5%, Germany - 6,9%.
#
# Пользователи используют приложение через следующие устройства: iPhone, Mac, Android, PC. Наибольшая доля платящих пользователей приходится на iPhone - 38,1% платящих пользователей. Далее идут устройства на Android - 23,1%, Mac - 21,5%, PC - 17,3%.
#
# Перечень каналов привлечения представлен следующим образом: AdNonSense, FaceBoom, LeapBob, MediaTornado, OppleCreativeMedia, RocketSuperAds, TipTop, WahooNetBanner, YRabbit, lambdaMediaAds, organic. Наибольшая доля пользователей приходит в приложение органически - 37,6%. Топ-5 каналов привлечения по доле платящих пользователей состоит из FaceBoom - 40,1%, TipTop - 21,1%, organic - 13,1%, WahooNetBanner - 5,1%, AdNonSense - 5,0%.
#
# </div>

# %% [markdown]
# ## Исследование затрат на маркетинг

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color='Black'>
#
# Проанализируем:
# - Сколько денег потратили? Всего / на каждый источник / по времени
# - Сколько в среднем стоило привлечение одного покупателя из каждого источника?
#
# </font>
# </div>

# %%
print(f"Общая сумма затрат на рекламу составила {costs['costs'].sum():.0f}")
# Out:
# Общая сумма затрат на рекламу составила 105497

# %%
# сгруппируем затраты на рекламу по каналам привлечения
costs_group = costs.groupby('channel').agg({'costs':'sum'}).sort_values('costs', ascending=False)

# найдем долю затрат на рекламу для каждого канала привлечения от общей величины затрат на рекламу
costs_group['%'] = round(costs_group['costs'] / costs_group['costs'].sum() * 100, 2)
display(costs_group)

# построим столбчатую диаграмму
# распределения затрат на рекламу по каналам привлечения
plt.figure(figsize=(18, 6))
plt.title('Распределение затрат на рекламу по каналам привлечения')

sns.barplot(x=costs_group.index, y=costs_group['costs'])

plt.xlabel('Канал привлечения')
plt.ylabel('Затраты на рекламу');
# Out:
#                        costs      %
# channel
# TipTop              54751.30  51.90
# FaceBoom            32445.60  30.75
# WahooNetBanner       5151.00   4.88
# AdNonSense           3911.25   3.71
# OppleCreativeMedia   2151.25   2.04
# RocketSuperAds       1833.00   1.74
# LeapBob              1797.60   1.70
# lambdaMediaAds       1557.60   1.48
# MediaTornado          954.48   0.90
# YRabbit               944.22   0.90

# %%
# построим сводную таблицу суммарных затрат на рекламу по датам и каналам привлечения
costs_pivot = costs.pivot_table(index='dt', columns='channel', values='costs', aggfunc='sum')
costs_pivot
# Out:
# channel     AdNonSense  FaceBoom  LeapBob  MediaTornado  OppleCreativeMedia  \
# dt
# 2019-05-01       40.95     113.3     2.52          6.24                4.25
# 2019-05-02       34.65      78.1     2.94          5.04                4.25
# 2019-05-03       47.25      85.8     2.73          6.96                5.75
# 2019-05-04       51.45     136.4     3.99          9.36                4.25
# 2019-05-05       36.75     122.1     4.62         11.04                5.50
# ...                ...       ...      ...           ...                 ...
# 2019-10-23       15.75     178.2    10.71          5.28               13.25
# 2019-10-24       21.00     222.2    12.81          5.04               12.50
# 2019-10-25       26.25     255.2    14.70          6.24               16.50
# 2019-10-26       21.00     272.8    14.28          6.72               14.25
# 2019-10-27       35.70     233.2    12.81          4.56               17.75
#
# ...

# %%
# построим график распределения кумулятивных затрат
# на рекламу по каналам привлечения во времени
plt.figure(figsize=(18,9))
plt.title('Распределение затрат на рекламу по каналам привлечения во времени')

sns.lineplot(data=costs_pivot);

plt.grid()
plt.xlabel('Даты')
plt.ylabel('Затраты на рекламу');

# %%
# рассчитаем средний CAC на одного пользователя для всего проекта
# без учета пользователей, привлеченных через органический трафик
user_profiles.query('channel != "organic"')['acquisition_cost'].mean()
# Out:
# 1.1274813239427588

# %%
# рассчитаем средний CAC на одного пользователя для каждого источника трафика
user_profiles_group = (user_profiles
                      .groupby('channel')
                      .agg({'acquisition_cost':'mean'})
                      .sort_values('acquisition_cost', ascending=False))
user_profiles_group
# Out:
#                     acquisition_cost
# channel
# TipTop                      2.799003
# FaceBoom                    1.113286
# AdNonSense                  1.008054
# lambdaMediaAds              0.724802
# WahooNetBanner              0.602245
# RocketSuperAds              0.412095
# OppleCreativeMedia          0.250000
# YRabbit                     0.218975
# MediaTornado                0.218717
# LeapBob                     0.210172
# organic                     0.000000

# %%
# построим график распределения стоимости привлечения клиента
# по каналам привлечения 
plt.figure(figsize=(18, 6))
plt.title('Распределение стоимости привлечения клиента по каналам привлечения')

sns.barplot(x=user_profiles_group.index, y=user_profiles_group['acquisition_cost'])

plt.axhline(user_profiles.query('channel != "organic"')['acquisition_cost'].mean(), 
            color='blue', linestyle='--', label='mean_CAC')

plt.legend()
plt.xlabel('Канал привлечения')
plt.ylabel('Стоимость привлечения клиента');

# %% [markdown]
# <div style="border:solid green 3px; padding: 20px">
#
# **Промежуточный вывод**
#
# Общая сумма расходов на маркетинг составила 105 497.
#
# Топ-5 каналов привлечения по доле затрат на рекламу состоит из TipTop - 51,9%, FaceBoom - 30,8%, WahooNetBanner - 4,9%, AdNonSense - 3,7%, OppleCreativeMedia - 2,0%. Наибольшие затраты на рекламу приходятся на каналы привлечения TipTop и FaceBoom, при этом максимальные значения затрат достигаются во второй половине сентября - начале октября 2019 года.
#
#
# Средняя стоимость привлечения одного пользователя составила 1,13. По каналу привлечения TipTop средняя стоимость привлечения одного пользователя превысила среднюю стоимость привлечения одного пользователя по всему проекту в целом и составила 2,8 ( почти в 2,5 раза больше относительно всего проекта).
#
#
# </div>

# %% [markdown]
# ## Оценка окупаемости рекламы для привлечения пользователей

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color='Black'>
#
# Проведем оценку в предположении того, что мы смотрим на данные 1-го ноября 2019 года и что окупаемость должна наступать не позднее, чем через 2 недели после привлечения пользователей.
#
# </font>
# </div>

# %%
# зададим момент анализа и горизонт анализа
observation_date = datetime(2019, 11, 1).date()
horizon_days = 14

# зададим лайфтайм для оценки динамики и 
# размер окна для построения скользящего среднего
horizon = 14
window = 14

# отфильтруем датафреймы с пользовательскими профилями и с логами посещений,  
# исключив пользователей, привлеченных через органический трафик
user_profiles_filtered = user_profiles.query('channel != "organic"')
visits_filtered = visits.query('channel != "organic"')

# %% [markdown]
# ### Анализ общей окупаемости рекламы

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color='Black'>
#
# Проанализируем общую окупаемость рекламы. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
#
# </font>
# </div>

# %%
# воспользуемся функцией для расчета LTV и ROI
raw_data, ltv, ltv_in_time, roi, roi_in_time = get_ltv(user_profiles_filtered, orders, observation_date, 
                                                       horizon_days, dimensions=[])

# %%
# воспользуемся функцией для визуализации LTV и ROI
print('Анализ общей окупаемости рекламы')
plot_ltv_roi(ltv, ltv_in_time, roi, roi_in_time, horizon, window=window)
# Out:
# Анализ общей окупаемости рекламы

# %% [markdown]
# <div style="border:solid green 3px; padding: 20px">
#
# **Промежуточный вывод**
#
# В целом реклама не окупается. ROI в конце 2-ой недели приближается к 80%. При этом на графике динамики ROI можно отметить нисходящий тренд и за май 2019 года реклама окупалась к концу второй недели.
#
# CAC растет, начиная с мая 2019 года, при этом к концу октября 2019 года рост значительный почти в 3 раза. Возможная причина убытков в увеличении рекламного бюджета.
#
# На графике динамики LTV наблюдаются колебания, вероятно, влияет сезонный фактор.
#
# </div>

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по устройствам

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color='Black'>
#
# Проанализируем окупаемость рекламы с разбивкой по устройствам. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
#
# </font>
# </div>

# %%
# воспользуемся функцией для расчета LTV и ROI
dimensions = ['device']
raw_data, ltv, ltv_in_time, roi, roi_in_time = get_ltv(user_profiles_filtered, orders, observation_date, 
                                                       horizon_days, dimensions=dimensions)

# %%
# воспользуемся функцией для визуализации LTV и ROI
print('Анализ окупаемости рекламы с разбивкой по устройствам')
plot_ltv_roi(ltv, ltv_in_time, roi, roi_in_time, horizon, window=window)
# Out:
# Анализ окупаемости рекламы с разбивкой по устройствам

# %% [markdown]
# <div style="border:solid green 3px; padding: 20px">
#
# **Промежуточный вывод**
#
# Видим, что по устройству PC реклама окупается к 11-дню, для Android, iPhone и Mac реклама не окупается. При этом на графике динамики ROI можно отметить нисходящий тренд для всех устройств. Начиная с сентября 2019 года, реклама не окупается для всех устройств.
#
# CAC по всем устройствам растет, начиная с конца мая 2019 года, при этом значительный рост наблюдается для iPhone и Mac, далее Android.
#
# На графике динамики LTV наблюдаются колебания, вероятно, влияет сезонный фактор.
#
# Можно сделать вывод, что одна из причин неокупаемости пользователей устройств Android, iPhone и Mac в повышенных затратах на рекламу.
#
# </div>

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по странам

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color='Black'>
#
# Проанализируем окупаемость рекламы с разбивкой по странам. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
#
# </font>
# </div>

# %%
# воспользуемся функцией для расчета LTV и ROI
dimensions = ['region']
raw_data, ltv, ltv_in_time, roi, roi_in_time = get_ltv(user_profiles_filtered, orders, observation_date, 
                                                       horizon_days, dimensions=dimensions)

# %%
# воспользуемся функцией для визуализации LTV и ROI
print('Анализ окупаемости рекламы с разбивкой по странам')
plot_ltv_roi(ltv, ltv_in_time, roi, roi_in_time, horizon, window=window)
# Out:
# Анализ окупаемости рекламы с разбивкой по странам

# %% [markdown]
# <div style="border:solid green 3px; padding: 20px">
#
# **Промежуточный вывод**
#
# Видим, что по странам UK, Germany, France реклама окупается к концу первой недели, по пользователям, привлеченным из United States, реклама не окупается к концу второй недели жизни. График динамики ROI также подтверждает, что пользователи из стран UK, Germany, France окупаются, пользователи из United States не окупаются, начиная с конца мая 2019 года.
#
# CAC по странам UK, Germany, France относительно стабилен, в начале июня наблюдается снижение, значительный рост с середины мая 2019 года наблюдается для United States.
#
# При этом LTV для United States выше, чем для других стран.
#
# Можно сделать вывод, что одна из причин неокупаемости пользователей из United States в повышенных затратах на рекламу.
#
# </div>

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по рекламным каналам

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color='Black'>
#
# Проанализируем окупаемость рекламы с разбивкой по рекламным каналам. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
#
# </font>
# </div>

# %%
# воспользуемся функцией для расчета LTV и ROI
dimensions = ['channel']
raw_data, ltv, ltv_in_time, roi, roi_in_time = get_ltv(user_profiles_filtered, orders, observation_date, 
                                                       horizon_days, dimensions=dimensions)

# %%
# воспользуемся функцией для визуализации LTV и ROI
print('Анализ окупаемости рекламы с разбивкой по рекламным каналам')
plot_ltv_roi(ltv, ltv_in_time, roi, roi_in_time, horizon, window=window)
# Out:
# Анализ окупаемости рекламы с разбивкой по рекламным каналам

# %% [markdown]
# <div style="border:solid green 3px; padding: 20px">
#
# **Промежуточный вывод**
#
# Для большинства каналов привлечения реклама окупается, за исключением следующих  TipTop, AdNonSense, FaceBoom.
#
# CAC для большинства каналов привлечения стабилен, для TipTop наблюдается значительный рост с середины мая 2019 года. При этом можно отметить, что для AdNonSense и FaceBoom стоимость привлечения одного клиента выше, чем для ругих каналов (за исключением TipTop, для которого CAC достигает наибольшего значения).
#
# При этом LTV для TipTop находится на высоком уровне и уступает только lambdaMediaAds.
#
# Можно сделать вывод, что одна из причин неокупаемости пользователей, привлеченных по каналам TipTop, AdNonSense, FaceBoom в повышенных затратах на рекламу.
#
# </div>

# %% [markdown]
# ### Анализ конверсии и удержания

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color='Black'>
#
# Построим графики конверсии и удержания с разбивкой по устройствам, странам, рекламным каналам.
#
# </font>
# </div>

# %%
# воспользуемся функцией для расчета удержания
raw_data, retention, retention_in_time = get_retention(user_profiles_filtered, visits_filtered, observation_date, 
                                                       horizon_days, dimensions=[])
retention
# Out:
#        cohort_size    0         1         2         3         4         5  \
# payer
# False        81334  1.0  0.173027  0.084553  0.050705  0.032828  0.024221
# True          7310  1.0  0.377428  0.288372  0.232011  0.208755  0.188919
#
#               6         7         8         9        10        11        12  \
# payer
# False  0.018295  0.013992  0.011262  0.009344  0.007365  0.006270  0.005852
# True   0.164843  0.154856  0.143639  0.135568  0.134200  0.120383  0.117373
#
#              13
# payer
# False  0.004598
# True   0.103420

# %%
# воспользуемся функцией для визуализации удержания
print('Анализ удержания')
plot_retention(retention, retention_in_time, horizon, window=window)
# Out:
# Анализ удержания

# %%
# воспользуемся функцией для расчета конверсии
raw_data, conversion, conversion_in_time = get_conversion(user_profiles_filtered, orders, observation_date, 
                                                          horizon_days, dimensions=[])
conversion
# Out:
#            cohort_size       0.0       1.0       2.0       3.0     4.0  \
# cohort
# All users        88644  0.058752  0.066321  0.069999  0.072571  0.0745
#
#                 5.0       6.0       7.0       8.0       9.0      10.0  \
# cohort
# All users  0.075775  0.076745  0.077591  0.078291  0.078945  0.079362
#
#                11.0      12.0      13.0
# cohort
# All users  0.079678  0.079904  0.080197

# %%
# воспользуемся функцией для визуализации конверсии
print('Анализ конверсии')
plot_conversion(conversion, conversion_in_time, horizon, window=window)
# Out:
# Анализ конверсии

# %%
dimensions = ['device']
# воспользуемся функцией для расчета удержания
raw_data, retention, retention_in_time = get_retention(user_profiles_filtered, visits_filtered, observation_date, 
                                                       horizon_days, dimensions=dimensions)
# воспользуемся функцией для визуализации удержания
print('Анализ удержания с разбивкой по устройствам')
plot_retention(retention, retention_in_time, horizon, window=window)
# Out:
# Анализ удержания с разбивкой по устройствам

# %%
dimensions = ['device']
# воспользуемся функцией для расчета конверсии
raw_data, conversion, conversion_in_time = get_conversion(user_profiles_filtered, orders, observation_date, 
                                                          horizon_days, dimensions=dimensions)
# воспользуемся функцией для визуализации конверсии
print('Анализ конверсии с разбивкой по устройствам')
plot_conversion(conversion, conversion_in_time, horizon, window=window)
# Out:
# Анализ конверсии с разбивкой по устройствам

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color='Black'>
#
# Исходя из анализа графиков конверсии и удержания, можно сделать вывод, что конверсия пользователей устройств Android, iPhone и Mac выше конверсии пользователей PC.
#
# При этом удержание платящих пользователей PC немного выше удержания пользователей других устройств.
#
# </font>
# </div>

# %%
dimensions = ['region']
# воспользуемся функцией для расчета удержания
raw_data, retention, retention_in_time = get_retention(user_profiles_filtered, visits_filtered, observation_date, 
                                                       horizon_days, dimensions=dimensions)
# воспользуемся функцией для визуализации удержания
print('Анализ удержания с разбивкой по странам')
plot_retention(retention, retention_in_time, horizon, window=window)
# Out:
# Анализ удержания с разбивкой по странам

# %%
dimensions = ['region']
# воспользуемся функцией для расчета конверсии
raw_data, conversion, conversion_in_time = get_conversion(user_profiles_filtered, orders, observation_date, 
                                                          horizon_days, dimensions=dimensions)
# воспользуемся функцией для визуализации конверсии
print('Анализ конверсии с разбивкой по странам')
plot_conversion(conversion, conversion_in_time, horizon, window=window)
# Out:
# Анализ конверсии с разбивкой по странам

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color='Black'>
#
# Исходя из анализа графиков конверсии и удержания, можно сделать вывод, что конверсия пользователей из United States значительно превышает конверсию пользователей из других стран.
#
# При этом удержание пользователей из United States ниже удержания пользователей из других стран.
#
# </font>
# </div>

# %%
dimensions = ['channel']
# воспользуемся функцией для расчета удержания
raw_data, retention, retention_in_time = get_retention(user_profiles_filtered, visits_filtered, observation_date, 
                                                       horizon_days, dimensions=dimensions)
# воспользуемся функцией для визуализации удержания
print('Анализ удержания с разбивкой по каналам привлечения')
plot_retention(retention, retention_in_time, horizon, window=window)
# Out:
# Анализ удержания с разбивкой по каналам привлечения

# %%
dimensions = ['channel']
# воспользуемся функцией для расчета конверсии
raw_data, conversion, conversion_in_time = get_conversion(user_profiles_filtered, orders, observation_date, 
                                                          horizon_days, dimensions=dimensions)
# воспользуемся функцией для визуализации конверсии
print('Анализ конверсии с разбивкой по каналам привлечения')
plot_conversion(conversion, conversion_in_time, horizon, window=window)
# Out:
# Анализ конверсии с разбивкой по каналам привлечения

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color='Black'>
#
# Исходя из анализа графиков конверсии и удержания, можно сделать вывод, что конверсия пользователей, привлеченных по каналам TipTop, AdNonSense, FaceBoom, находится на достаточно высоком уровне относительно конверсии пользователей, привлеченных по другим каналам привлечения.
#
# При этом удержание пользователей, привлеченных по каналам AdNonSense, FaceBoom  находится существенно ниже удержания пользователей, привлеченных по другим каналам привлечения.
#
# </font>
# </div>

# %%
# используя профили платящих пользователей,
# построим сводную таблицу по странам 
# в разбивке по устройствам
pivot = (user_profiles.query('payer == True and channel != "organic"')
        .pivot_table(index='region', 
                     columns='device', 
                     values='user_id', 
                     aggfunc='nunique'))
# добавляем столбец с суммой по строкам
pivot['all'] = pivot.sum(axis=1)

# задаём размер графика
plt.figure(figsize=(18, 9))   
sns.heatmap(
    (pivot / pivot['all'].sum())
    .fillna(0)
    .drop(columns='all'),     # удаляем суммирующий столбец
    annot=True,               # включаем подписи
    fmt='.2%',                # переводим значения в проценты
)
# название графика
plt.title('Тепловая карта распределения платящих пользователей по странам и устройствам') 
plt.show()

# %%
# используя профили платящих пользователей,
# построим сводную таблицу по каналам привлечения
# в разбивке по странам
pivot = (user_profiles.query('payer == True and channel != "organic"')
        .pivot_table(index='channel', 
                     columns='region', 
                     values='user_id', 
                     aggfunc='nunique'))
# добавляем столбец с суммой по строкам
pivot['all'] = pivot.sum(axis=1)

# задаём размер графика
plt.figure(figsize=(18, 9))   
sns.heatmap(
    (pivot / pivot['all'].sum())
    .fillna(0)
    .drop(columns='all'),     # удаляем суммирующий столбец
    annot=True,               # включаем подписи
    fmt='.2%',                # переводим значения в проценты
)
# название графика
plt.title('Тепловая карта распределения платящих пользователей по каналам привлечения и странам') 
plt.show()

# %% [markdown]
# <div style="border:solid green 3px; padding: 20px">
#
# **Промежуточный вывод**
#
# По проекту в целом  реклама не окупается. При более детальном анализе мы выяснили, что в разбивке по устройствам реклама не окупается по пользователям Android, iPhone и Mac, в разбивке по странам реклама не окупается по пользователям из United States, в разбивке по каналам привлечения реклама не окупается по каналам TipTop, AdNonSense, FaceBoom. Одна из причин неокупаемости высокие затраты на рекламу.
#
# На основе тепловых карт можно сделать вывод о том, что существенная доля платящих пользователей устройств Android, iPhone и Mac из United States, для платящих пользователей из United States основными каналами привлечения являются TipTop и FaceBoom, при чем по данным каналам привлекаются только пользователи из United States.
#
# Исходя из анализа графиков конверсии и удержания, можно сделать вывод, что конверсия пользователей устройств  Android, iPhone и Mac выше конверсии пользователей PC, конверсия пользователей из United States выше конверсии пользователей из других стран, конверсия пользователей, привлеченных по каналам TipTop, AdNonSense, FaceBoom, находится на достаточно высоком уровне относительно конверсии пользователей, привлеченных по другим каналам привлечения.
#
# При этом удержание пользователей устройств Android, iPhone и Mac ниже удержания пользователей PC, удержание пользователей из United States существенно ниже удержания пользователей из других стран, удержание пользователей, привлеченных по каналам AdNonSense, FaceBoom  находится существенно ниже удержания пользователей, привлеченных по другим каналам привлечения.
#
# Можно предположить, что причины низкого удержания пользователей из United States связаны с техническими проблемами, например, с трудностями при оплате из United States. Причины низкого удержания пользователей, привлеченных по каналу FaceBoom, скорее всего, напрямую связаны с низким удержанием пользователей из United States, так как по каналу привлечения FaceBoom привлекаются только пользователи из United States. Причины низкого удержания пользователей, привлеченных по каналу AdNonSense требуют дополнительного анализа.
#
# </div>

# %% [markdown]
# ## Общие выводы

# %% [markdown]
# <div style="border:solid green 3px; padding: 20px">
#
# - **Краткий обзор проекта**
#
#     Провели исследование окупаемости приложения Procrastinate Pro+ на основе данных о пользователях, привлечённых с 1 мая по 27 октября 2019 года: лога сервера с данными об их посещениях, выгрузки их покупок за этот период, рекламных расходов за период.
#
#
# - **Главные выводы**
#
#     По проекту в целом  реклама не окупается. При более детальном анализе мы выяснили, что в разбивке по устройствам реклама не окупается по пользователям Android, iPhone и Mac, в разбивке по странам реклама не окупается по пользователям из United States, в разбивке по каналам привлечения реклама не окупается по каналам TipTop, AdNonSense, FaceBoom.
#
#     Одна из причин неокупаемости высокие затраты на рекламу по каналам привлечения TipTop, AdNonSense, FaceBoom.
#
#     Также выявили, что удержание пользователей из United States существенно ниже удержания пользователей из других стран, удержание пользователей, привлеченных по каналам AdNonSense, FaceBoom  находится существенно ниже удержания пользователей, привлеченных по другим каналам привлечения.
#
#     Существенная доля платящих пользователей устройств Android, iPhone и Mac приходится на United States, для платящих пользователей из United States основными каналами привлечения являются TipTop и FaceBoom, при чем по данным каналам привлекаются только пользователи из United States.
#
#     Можно предположить, что причины низкого удержания пользователей из United States связаны с техническими проблемами, например, с трудностями при оплате из United States. Причины низкого удержания пользователей, привлеченных по каналу FaceBoom, скорее всего, напрямую связаны с низким удержанием пользователей из United States, так как по каналу привлечения FaceBoom привлекаются только пользователи из United States. Причины низкого удержания пользователей, привлеченных по каналу AdNonSense требуют дополнительного анализа.
#
#
# - **Рекомендации**
#
#     Для повышения эффективности привлечения пользователей рекомендуется снизить затраты на рекламу по каналам привлечения TipTop, AdNonSense, FaceBoom, так как ROI по данным каналам находится ниже уровня 100% к концу второй недели.
#
#     Также совместно с разработчиками необходимо выяснить причины низкого удержания пользователей из United States, которые могут быть связаны, например, с трудностями при оплате из United States.
#
# </div>
